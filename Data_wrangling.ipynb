# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
kashti = sns.load_dataset('titanic')
ks1 = kashti
ks2 = kashti
ks = sns.load_dataset('titanic')

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
(kashti['age']+10).head(10)
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# 5     NaN
# 6    64.0
# 7    12.0
# 8    37.0
# 9    24.0
# Name: age, dtype: float64

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
print(kashti.shape)
kashti.dropna(subset =['deck'], axis = 0,inplace=True)
# Out:
# (891, 15)

# %%
kashti.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
kashti = kashti.dropna()
kashti.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.shape
# Out:
# (182, 15)

# %%
ks1.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
mean = ks1['age'].mean()
mean
# Out:
# 35.77945652173913

# %%
ks1['age'] = ks1['age'].replace(np.nan, mean)

# %%
ks1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
ks1['embarked'] = ks1['embarked'].replace(np.nan, mean)

# %%
ks1['embark_town'] = ks1['embark_town'].replace(np.nan, mean)

# %%
ks1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
kashti['survived'] = kashti['survived'].astype('int64')
kashti.dtypes
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11928\2043644328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kashti['survived'] = kashti['survived'].astype('int64')
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
ks1['age'] = ks1['age'].astype('int64')
ks1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age               int64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
ks1['age'] = ks1['age']*365
ks1.head()
# Out:
#     survived  pclass     sex    age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  13870      1      0  71.2833        C  First
# 3          1       1  female  12775      1      0  53.1000        S  First
# 6          0       1    male  19710      0      0  51.8625        S  First
# 10         1       3  female   1460      1      1  16.7000        S  Third
# 11         1       1  female  21170      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
ks1.rename(columns={'age' : 'age in days'}, inplace = True)

# %%
ks1.head()
# Out:
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1          1       1  female        13870      1      0  71.2833        C
# 3          1       1  female        12775      1      0  53.1000        S
# 6          0       1    male        19710      0      0  51.8625        S
# 10         1       3  female         1460      1      1  16.7000        S
# 11         1       1  female        21170      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %%
kashti.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
ks4 = kashti[['age', 'fare']]
ks4.head()
# Out:
#      age     fare
# 1   38.0  71.2833
# 3   35.0  53.1000
# 6   54.0  51.8625
# 10   4.0  16.7000
# 11  58.0  26.5500

# %%
ks4['fare'] = ks4['fare']/ks4['fare'].max()
ks4.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11928\1832173846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = ks4['fare']/ks4['fare'].max()
#      age      fare
# 1   38.0  0.139136
# 3   35.0  0.103644
# 6   54.0  0.101229
# 10   4.0  0.032596
# 11  58.0  0.051822

# %%
ks4['age'] = ks4['age']/ks4['age'].max()
ks4.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11928\1914199142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['age'] = ks4['age']/ks4['age'].max()
#        age      fare
# 1   0.4750  0.139136
# 3   0.4375  0.103644
# 6   0.6750  0.101229
# 10  0.0500  0.032596
# 11  0.7250  0.051822

# %%
ks4['fare'] = (ks4['fare'] - ks4['fare'].min())  / (ks4['fare'] - ks4['fare'].max())
ks4.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11928\4060025793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = (ks4['fare'] - ks4['fare'].min())  / (ks4['fare'] - ks4['fare'].max())
#        age      fare
# 1   0.4750 -0.161623
# 3   0.4375 -0.115629
# 6   0.6750 -0.112630
# 10  0.0500 -0.033695
# 11  0.7250 -0.054654

# %%
kashti['fare'] =(kashti['fare'] - kashti['fare'].mean()) / kashti['fare'].std()
kashti.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11928\3621729546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kashti['fare'] =(kashti['fare'] - kashti['fare'].mean()) / kashti['fare'].std()
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1          1       1  female  38.0      1      0 -0.099835        C  First
# 3          1       1  female  35.0      1      0 -0.337554        S  First
# 6          0       1    male  54.0      0      0 -0.353732        S  First
# 10         1       3  female   4.0      1      1 -0.813428        S  Third
# 11         1       1  female  58.0      0      0 -0.684654        S  First
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
ks4['fare'] = np.log(ks4['age'])
ks4.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11928\296641939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare'] = np.log(ks4['age'])
#        age      fare
# 1   0.4750 -0.744440
# 3   0.4375 -0.826679
# 6   0.6750 -0.393043
# 10  0.0500 -2.995732
# 11  0.7250 -0.321584

# %%
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
bins = np.linspace(min(ks['age']), max(max['ks']), 1500)
age_group = ['bachay', 'jawan', 'boorhay']
ks['age'] = pd.cut(ks['age'] , bins =  , labels = age_group , include_lowest= True)
ks['age']
# Out:
#   Input In [318]
#     ks['age'] = pd.cut(ks['age'] , bins =  , labels = age_group , include_lowest= True)
#                                            ^
# SyntaxError: invalid syntax

# %%
pd.get_dummies(ks['sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
ks.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  22.0      1      0   7.2500        S  Third    man
# 1         1       1  38.0      1      0  71.2833        C  First  woman
# 2         1       3  26.0      0      0   7.9250        S  Third  woman
# 3         1       1  35.0      1      0  53.1000        S  First  woman
# 4         0       3  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  sex_male
# 0        True  NaN  Southampton    no  False         1
# 1       False    C    Cherbourg   yes  False         0
# 2       False  NaN  Southampton   yes   True         0
# 3       False    C  Southampton   yes  False         0
# 4        True  NaN  Southampton    no   True         1
